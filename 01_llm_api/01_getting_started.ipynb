# %% [markdown]
# ## ***Imports and Setup***

# %%
# Install required packages
# Run this cell once, then restart kernel

# %pip install groq
# %pip install sentence-transformers
# %pip install tf-keras
# %pip install numpy
# %pip install python-dotenv

# %%
import os
from dotenv import load_dotenv
from groq import Groq

load_dotenv()
client = Groq(api_key=os.getenv("GROQ_API_KEY"))
MODEL = os.getenv("GROQ_MODEL")
print("Client ready ..")
# Out:
# Client ready ..

# %% [markdown]
# ## ***API Call***

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "What is a large language model in 2 sentences?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# A large language model is a type of artificial intelligence (AI) system designed to process and generate human-like language, capable of understanding and responding to complex text-based inputs with high accuracy and speed. These models, such as those in the transformer architecture, are typically trained on massive datasets and have millions of parameters, enabling them to learn patterns and relationships in language and generate text that is coherent, informative, and often creative.

# %% [markdown]
# ## ***System prompt control***

# %%
response = client.chat.completions.create(
    model=MODEL,
    messages=[
        {"role": "system", "content": "You are an AI engineering tutor. Give concise, technical answers with code examples."},
        {"role": "user", "content": "Explain what a transformer is in simple terms."}
    ]
)

print(response.choices[0].message.content)
# Out:
# **Transformer: A Deep Learning Model**
#
# Imagine you have a conversation with a friend. To understand what they're saying, you don't just focus on each individual word; you consider the entire sentence, its structure, and context. This is similar to how a transformer works in deep learning.
#
# A **transformer** is a type of neural network architecture that excels at processing sequential data, like sentences or time series. Unlike traditional recurrent neural networks (RNNs), transformers do not rely on explicit loops or states.
#
# **Key components:**
#
# 1. **Self-Attention Mechanism**: This is the core of the transformer. It allows the model to focus on all parts of the input simultaneously and weigh their importance for the output.
# 2. **Encoder**: Takes in input data and outputs a set of vectors, called key-value pairs.
# 3. **Decoder**: Takes in these vectors and generates output.
#
# **How it works:**
#
# ...

# %% [markdown]
# ## ***Multi turn Conversation***

# %%
messages = [
    {"role": "system", "content": "You are a helpful AI assistant."}
]

def chat(user_input):
    messages.append({"role": "user", "content": user_input})
    response = client.chat.completions.create(
        model=MODEL,
        messages=messages
    )
    reply = response.choices[0].message.content
    messages.append({"role": "assistant", "content": reply})
    return reply

# Test it
print(chat("My name is Adi and I'm learning AI engineering."))
print(chat("What's my name and what am I learning?"))
# Out:
# Nice to meet you, Adi. AI engineering is an exciting field, and I'm here to help you learn and grow in your journey. What specific areas of AI engineering are you interested in or would like to learn more about? Are you working on a project or looking for resources to study?
#
# To get started, I can suggest some topics or provide information on the following areas:
#
# 1. Machine Learning (ML) and Deep Learning (DL)
# 2. Natural Language Processing (NLP)
# 3. Computer Vision (CV)
# 4. Robotics
# 5. AI frameworks and tools (e.g., TensorFlow, PyTorch, Keras)
#
# Let me know where you'd like to begin, and I'll be happy to assist you!
# Your name is Adi, and you are learning AI engineering.
